# %%
# Installation automatique des dépendances requises dans le noyau Jupyter actuel
# %pip install -r ../requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 📥 Étape 1 : Acquisition des Données & Multi-Sources (Squelette Étudiant)
#
# Cette étape correspond au premier chapitre du pipeline de Data Science. L'objectif est d'identifier, d'importer et de consolider vos jeux de données bruts issus de différentes sources (fichiers CSV locaux, requêtes API, bases de données, etc.).

# %% [markdown]
# ### 1. Initialisation de l'environnement

# %%
import os
import sys
import pandas as pd
import numpy as np

# Ajout du dossier parent au chemin de recherche des modules
sys.path.append(os.path.abspath('..'))

print("Libraries importées avec succès ! Prêt pour l'étape d'Acquisition des Données.")
# Out:
# Libraries importées avec succès ! Prêt pour l'étape d'Acquisition des Données.

# %% [markdown]
# ### 2. Chargement de la source de données principale
#
# Le jeu de données a été chargé à partir de ce dataset :
#
# [Uncleaned Laptop Price Dataset](https://www.kaggle.com/datasets/ehtishamsadiq/uncleaned-laptop-price-dataset/data)
#
# L'ensemble de données de ce dataset représente une collection d'annonces d'ordinateurs portables extraites d'un site de commerce électronique.
#
# ### 🔹 Date du dataset : **2019**
#
# ### 🔹 Dimension du dataset : **1 300 ordinateurs portables**
#
# ### 🔹 Variables catégorielles
# * **marque**
# * **modèle**
# * **résolution d'écran**
# * **type de processeur**
# * **système d'expoitation**
# * **...**
#
# ### 🔹 Variables numériques
# * **taille de l'écran**
# * **mémoire**
# * **capacité de stockage**
# * **prix**
# * **...**

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Load a DataFrame with a specific version of a CSV
df = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "unsdsn/world-happiness/versions/1",
    "2016.csv",
)

# %%
# Spécifiez le chemin vers votre jeu de données principal
main_data_path = '../data/raw/laptopData.csv'

# TODO: Charger le dataset à l'aide de Pandas
df_main = pd.read_csv(main_data_path)

# Affichez la taille et les premières lignes
print(f"Vérification de la taille du dataset et visualisation des premières colonnes : {df_main.shape}")
df_main.head(20)
# Out:
# Vérification de la taille du dataset et visualisation des premières colonnes : (1303, 12)
#     Unnamed: 0 Company   TypeName Inches  \
# 0          0.0   Apple  Ultrabook   13.3
# 1          1.0   Apple  Ultrabook   13.3
# 2          2.0      HP   Notebook   15.6
# 3          3.0   Apple  Ultrabook   15.4
# 4          4.0   Apple  Ultrabook   13.3
# 5          5.0    Acer   Notebook   15.6
# 6          6.0   Apple  Ultrabook   15.4
# 7          7.0   Apple  Ultrabook   13.3
# 8          8.0    Asus  Ultrabook     14
# 9          9.0    Acer  Ultrabook     14
# 10        10.0      HP   Notebook   15.6
# 11        11.0      HP   Notebook   15.6
# 12        12.0   Apple  Ultrabook   15.4
# 13        13.0    Dell   Notebook   15.6
# 14        14.0   Apple  Ultrabook     12
# 15        15.0   Apple  Ultrabook   13.3
# 16        16.0    Dell   Notebook   15.6
# 17        17.0   Apple  Ultrabook   15.4
# 18        18.0  Lenovo   Notebook   15.6
# 19        19.0    Dell  Ultrabook   13.3
#
# ...

# %% [markdown]
# ### Conclusion
#
# Une première analyse du dataset est effectuée afin d’avoir une vision globale de sa structure et de son contenu.
#
# ### 🔹 Observations
#
# * **Nombre d'enregistrements :** 1303 lignes.
# * **Nombre de colonnes :** 12 colonnes.
# * **Types de variables observées :**
#   * des variables **catégorielles** comme la marque, le type d’ordinateur, le processeur, la carte graphique ou le système d’exploitation ;
#   * des variables **numériques** comme la taille de l’écran, la mémoire RAM, le poids ou le prix.
# * **Premiers constats :**
#   * certaines colonnes contiennent **plusieurs informations dans une seule valeur**;
#   * la colonne `Price` représente la **variable cible du projet**, puisqu’elle servira à analyser ou prédire le prix des ordinateurs.
#
# Cette première observation permet donc **d’identifier les principales variables disponibles** et de **repérer les colonnes qui nécessiteront un nettoyage ou une transformation** avant l’analyse exploratoire et la modélisation.
