# %%
# Installation automatique des dépendances requises dans le noyau Jupyter actuel
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: pandas>=2.0.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: numpy>=1.24.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 3)) (2.2.6)
# Requirement already satisfied: scikit-learn>=1.2.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 6)) (1.7.2)
# Requirement already satisfied: tensorflow>=2.12.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 7)) (2.21.0)
# Requirement already satisfied: matplotlib>=3.7.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 10)) (3.10.9)
# Requirement already satisfied: seaborn>=0.12.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 11)) (0.13.2)
# Requirement already satisfied: plotnine>=0.12.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 12)) (0.15.4)
# Requirement already satisfied: ipykernel in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 15)) (7.2.0)
# Requirement already satisfied: jupyter in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 16)) (1.1.1)
# Requirement already satisfied: quarto in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 17)) (0.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from pandas>=2.0.0->-r ../requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from pandas>=2.0.0->-r ../requirements.txt (line 2)) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from pandas>=2.0.0->-r ../requirements.txt (line 2)) (2026.2)
# Requirement already satisfied: scipy>=1.8.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from scikit-learn>=1.2.0->-r ../requirements.txt (line 6)) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from scikit-learn>=1.2.0->-r ../requirements.txt (line 6)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from scikit-learn>=1.2.0->-r ../requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.4.0)
# Requirement already satisfied: packaging in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (26.2)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2.34.2)
# Requirement already satisfied: setuptools in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (59.6.0)
# Requirement already satisfied: six>=1.12.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.12.2)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.15)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2026.4.22)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (1.5.0)
# Requirement already satisfied: pillow>=8 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (3.3.2)
# Requirement already satisfied: mizani~=0.14.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from plotnine>=0.12.0->-r ../requirements.txt (line 12)) (0.14.4)
# Requirement already satisfied: statsmodels>=0.14.6 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from plotnine>=0.12.0->-r ../requirements.txt (line 12)) (0.14.6)
# Requirement already satisfied: comm>=0.1.1 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (8.39.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (0.2.2)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (6.5.5)
# Requirement already satisfied: traitlets>=5.4.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (5.15.0)
# Requirement already satisfied: notebook in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyter->-r ../requirements.txt (line 16)) (7.5.6)
# Requirement already satisfied: jupyter-console in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyter->-r ../requirements.txt (line 16)) (6.6.3)
# Requirement already satisfied: nbconvert in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyter->-r ../requirements.txt (line 16)) (7.17.1)
# Requirement already satisfied: ipywidgets in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyter->-r ../requirements.txt (line 16)) (8.1.8)
# Requirement already satisfied: jupyterlab in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyter->-r ../requirements.txt (line 16)) (4.5.7)
# Requirement already satisfied: nbformat in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from quarto->-r ../requirements.txt (line 17)) (5.10.4)
# Requirement already satisfied: nbclient in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from quarto->-r ../requirements.txt (line 17)) (0.10.4)
# Requirement already satisfied: pyyaml in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from quarto->-r ../requirements.txt (line 17)) (6.0.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.47.0)
# Requirement already satisfied: decorator in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (5.3.1)
# Requirement already satisfied: exceptiongroup in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (0.20.0)
# Requirement already satisfied: pexpect>4.3 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (2.20.0)
# Requirement already satisfied: stack_data in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (0.6.3)
# Requirement already satisfied: wcwidth in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (0.8.7)
# Requirement already satisfied: platformdirs>=2.5 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->-r ../requirements.txt (line 15)) (4.9.6)
# Requirement already satisfied: rich in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from keras>=3.12.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (15.0.0)
# Requirement already satisfied: namex in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from keras>=3.12.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.1.0)
# Requirement already satisfied: optree in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from keras>=3.12.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.19.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (0.7.0)
# Requirement already satisfied: patsy>=0.5.6 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from statsmodels>=0.14.6->plotnine>=0.12.0->-r ../requirements.txt (line 12)) (1.0.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 16)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 16)) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.18.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.2.4)
# Requirement already satisfied: tomli>=1.2.2 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.4.1)
# Requirement already satisfied: anyio in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.14.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (4.26.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jinja2>=3.0.3->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (4.1.0)
# Requirement already satisfied: rfc3339-validator in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.1.1)
# Requirement already satisfied: fqdn in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.5.1)
# Requirement already satisfied: isoduration in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.1.0)
# Requirement already satisfied: uri-template in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 16)) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 16)) (6.3.0)
# Requirement already satisfied: defusedxml in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 16)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 16)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 16)) (3.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 16)) (1.5.1)
# Requirement already satisfied: webencodings in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 16)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 16)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from nbformat->quarto->-r ../requirements.txt (line 17)) (2.21.2)
# Requirement already satisfied: lark>=1.2.2 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.0.0)
# Requirement already satisfied: pycparser in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter->-r ../requirements.txt (line 16)) (2.8.3)
# Requirement already satisfied: arrow>=0.15.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from rich->keras>=3.12.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (4.2.0)
# Requirement already satisfied: mdurl~=0.1 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: executing>=1.2.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (3.0.1)
# Requirement already satisfied: pure-eval in /home/lili/Dev/aptispace-datascience-projet/venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 📥 Étape 1 : Acquisition des Données & Multi-Sources (Squelette Étudiant)
#
# Cette étape correspond au premier chapitre du pipeline de Data Science. L'objectif est d'identifier, d'importer et de consolider vos jeux de données bruts issus de différentes sources (fichiers CSV locaux, requêtes API, bases de données, etc.).

# %% [markdown]
# ### 1. Initialisation de l'environnement

# %%
import os
import sys
import pandas as pd
import numpy as np

# Ajout du dossier parent au chemin de recherche des modules
sys.path.append(os.path.abspath('..'))

print("Libraries importées avec succès ! Prêt pour l'étape d'Acquisition des Données.")
# Out:
# Libraries importées avec succès ! Prêt pour l'étape d'Acquisition des Données.

# %% [markdown]
# ### 2. Chargement de la source de données principale
#
# **À COMPLÉTER PAR L'ÉTUDIANT :**
# Chargez votre jeu de données principal (par exemple un fichier CSV stocké dans `data/raw/`).

# %%
# Spécifiez le chemin vers votre jeu de données principal
main_data_path = '../data/raw/laptopData.csv'

# TODO: Charger le dataset à l'aide de Pandas
df_main = pd.read_csv(main_data_path)

# Affichez la taille et les premières lignes
print(f"Dimensions du dataset principal : {df_main.shape}")
df_main.head()
# Out:
# Dimensions du dataset principal : (1303, 12)
#    Unnamed: 0 Company   TypeName Inches                    ScreenResolution  \
# 0         0.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1         1.0   Apple  Ultrabook   13.3                            1440x900
# 2         2.0      HP   Notebook   15.6                   Full HD 1920x1080
# 3         3.0   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4         4.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %% [markdown]
# ### 3. Intégration de données secondaires (Multi-Sources)
#
# L'analyse se base uniquement sur le dataset principal. Nous n'avons pas intégré de données secondaires.

# %%
# TODO: Récupérer/générer ou charger vos données secondaires
# Exemple fictif : création d'un DataFrame complémentaire avec des catégories/labels
# categories_info = pd.DataFrame({
#     'category': ['A', 'B', 'C'],
#     'description': ['Premium', 'Standard', 'Basique'],
#     'coef_multiplicateur': [1.5, 1.0, 0.8]
# })

# print("Données secondaires prêtes :")
# categories_info.head()

# %% [markdown]
# ### 4. Fusion des sources (Optionnel)
#
# **À COMPLÉTER PAR L'ÉTUDIANT :**
# Associez vos différentes sources de données en utilisant des jointures (`pd.merge`) pertinentes.

# %%
# # TODO: Effectuer la jointure de vos tables si nécessaire
# df_merged = pd.merge(df_main, categories_info, on='category', how='left')
# df_merged.head()

# %% [markdown]
# ### 5. Consignation des données d'entrée brutes
#
# Sauvegardez l'état brut de vos données d'entrée pour la suite du pipeline.

# %%
# Sauvegarde du fichier brute fusionné si applicable
print("Acquisition terminée avec succès !")
# Out:
# Acquisition terminée avec succès !
